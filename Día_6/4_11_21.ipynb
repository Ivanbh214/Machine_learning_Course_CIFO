# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanbh214/Machine_learning_Course_CIFO/blob/main/D%C3%ADa_6/4_11_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Overfitting**
#
# Cuando se produce overfitting el modelo deja de generalizar.
#
# Habría un punto óptimo entre el set de entreanmiento y el de validación. Donde se muestra un ligera mejora en la validación
# ![Overfiting.PNG](data:image/png;base64,...)

# %% [markdown]
# #**Python**
# **Funciones max, min, sum**
# Se pueden hacer con listas y tupplas (que son inmutables), también se puede hacer con la funcion range.

# %%
max([1,2,3,7,9, 6, 5, 0])
# Out:
# 9

# %%
min([1,2,3,7,9, 6, 5, 0])
# Out:
# 0

# %%
max(1,2,3)
# Out:
# 3

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
sum(range(1, 101))
# Out:
# 5050

# %%
def quadrat(x): return x*x

# %%
ll = list(range(1,101))

# %%
ll

# %% [markdown]
# **map()**
# https://www.geeksforgeeks.org/python-map-function/

# %%
x = map(quadrat, ll)

# %%
print(x)

# %%
list(x)
# Out:
# []

# %%
x = list(map(lambda x: x**3, ll))

# %%
print(x[:20])
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000, 1331, 1728, 2197, 2744, 3375, 4096, 4913, 5832, 6859, 8000]

# %% [markdown]
# **zip**
#
# Combina dos listas y crea una lista de tuplas

# %%
x = list(range(1,21))
y = list(range(1,21))

# %%
y = list(map(quadrat, y))

# %%
x, y

# %%
z = list(zip(x,y))

# %%
print(z)
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49), (8, 64), (9, 81), (10, 100), (11, 121), (12, 144), (13, 169), (14, 196), (15, 225), (16, 256), (17, 289), (18, 324), (19, 361), (20, 400)]

# %% [markdown]
# Se puede acceder a los elementos de cada tuppla, ya que se genera una estructura de árbol o anidado.

# %%
z[0]
# Out:
# (1, 1)

# %%
z[0][0]
# Out:
# 1

# %%
z[1][1]
# Out:
# 4

# %%
z[2][1]
# Out:
# 9

# %%
z[-1][0]
# Out:
# 20

# %%
z[-1][-1]
# Out:
# 400

# %% [markdown]
# **Separar listas**
#
# 1-Separa en función de los diferntes tipos de elementos de la lista
#
# https://www.geeksforgeeks.org/python-unzip-a-list-of-tuples/
#
# 2-Separa las 2 listas
#
# https://www.geeksforgeeks.org/python-split-nested-list-into-two-lists/

# %% [markdown]
# 1-Separa en función de los diferntes tipos de elementos de la lista

# %%
#separar dos listas
# initializing list of tuples
test_list = [('Akshat', 1), ('Bro', 2), ('is', 3), ('Placed', 4)]
  
# Printing original list
print ("Original list is : " + str(test_list))
# Out:
# Original list is : [('Akshat', 1), ('Bro', 2), ('is', 3), ('Placed', 4)]

# %%
test_list[0]
# Out:
# ('Akshat', 1)

# %%
# using list comprehension to
# perform Unzipping
res = [[ i for i, j in test_list ],
       [ j for i, j in test_list ]]

# %%
# Printing modified list 
print ("Modified list is : " + str(res))
# Out:
# Modified list is : [['Akshat', 'Bro', 'is', 'Placed'], [1, 2, 3, 4]]

# %%
res[0]
# Out:
# ['Akshat', 'Bro', 'is', 'Placed']

# %% [markdown]
# 2-Separa las 2 listas (añadiendo el *)
#
# Convierte cada elemento de la tuppla en una lista
#
# https://www.geeksforgeeks.org/python-split-nested-list-into-two-lists/
#
# Un dicciniario no puede ser clave en porque no es haseable
#
# Haseable, definición
#
# https://www.it-swarm-es.com/es/python/que-significa-hashable-en-python/1071742522/

# %%
# Python code to demonstrate
# splitting nested list
# into 2 lists
  
# initialising nested lists
ini_list = [[1, 2], [4, 3], [45, 65], [223, 2]]
  
# printing initial lists
print ("initial list", str(ini_list))
  
# code to split it into 2 lists
res1, res2 = map(list, zip(*ini_list))
  
# printing result
print("final lists", res1, "\n", res2)
# Out:
# initial list [[1, 2], [4, 3], [45, 65], [223, 2]]
# final lists [1, 4, 45, 223]
#  [2, 3, 65, 2]

# %%
#Solucion joan
list(zip(*z))

# %%
a = 2
b = 3

# %%
c = b
b = a

# %%
a
# Out:
# 2

# %%
b
# Out:
# 2

# %%
a, b = b, a

# %%
print(a, b)
# Out:
# 2 2

# %%
a, b = (2,3)

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
for a, b in [(1,2), (3,4)]: print(a,b)
# Out:
# 1 2
# 3 4

# %% [markdown]
# #**Glosario**
# lot = Batch
#
# epoca = epoch
#
# **Diferencias entre entrenamiento por batch and epoch**
#
# https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
#
# **Anadir mas capas a una red neuronal**
# https://machinelearningmastery.com/how-to-control-neural-network-model-capacity-with-nodes-and-layers/
#
# **Configurar en número de capas**
# https://machinelearningmastery.com/how-to-configure-the-number-of-layers-and-nodes-in-a-neural-network/
#
# **Cross Validation**
#
# https://es.wikipedia.org/wiki/Validaci%C3%B3n_cruzada#:~:text=La%20validaci%C3%B3n%20cruzada%20o%20cross,datos%20de%20entrenamiento%20y%20prueba.&text=%E2%80%8B%20Es%20una%20t%C3%A9cnica%20muy,artificial%20para%20validar%20modelos%20generados.
#
# https://scikit-learn.org/stable/modules/cross_validation.html
#
# https://machinelearningmastery.com/repeated-k-fold-cross-validation-with-python/

# %% [markdown]
# #**Mach
